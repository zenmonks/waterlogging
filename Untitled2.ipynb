# %% [markdown]
# <a href="https://colab.research.google.com/github/zenmonks/waterlogging/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 654.0/654.0 kB 8.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 214MB/s]

# %%
results = model.predict("cattest.jpeg")
# Out:
# image 1/1 /content/cattest.jpeg: 576x640 1 cat, 1346.4ms
# Speed: 3.7ms preprocess, 1346.4ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 640)

# %%
result = results[0]
print(len(result.boxes))
# Out:
# 1

# %%
for box in result.boxes:
    label = result.names[box.cls[0].item()]
    cords = [round(x) for x in box.xyxy[0].tolist()]
    prob = box.conf[0].item()
    print("Object type", label)
    print("coordinates", cords)
    print("Probability", prob)
    print(" === ")
# Out:
# Object type cat
# coordinates [1, 33, 185, 175]
# Probability 0.7686582207679749
#  ===

# %%
from PIL import Image
Image.fromarray(result.plot()[:,:,::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=238x212>
